# %% [markdown]
#  # 🏛️ Harvard’s Artifacts Collection: ETL, SQL Analytics & Streamlit Showcase

# %% [markdown]
# ## Project Statement

# %%
# Project Statement:-
    # Building an interactive, end-to-end ETL and data exploration platform using the Harvard Art Museums public API.
    # This platform will empower users to dynamically explore, collect, store, and query rich art collections from Harvard’s digital archive
    # using Streamlit web application.

# %% [markdown]
# ## 1.API Integration & Data Extraction

# %%
import requests

api_key = "a50a2e2e-f9f5-4654-81c0-1a92d1ec9951"
url = "https://api.harvardartmuseums.org/classification"  # Classification URL

params = {
    "apikey": api_key,
    "size": 100
}

response = requests.get(url, params=params)
data = response.json()

data
# Out:
# {'info': {'totalrecordsperquery': 100,
#   'totalrecords': 64,
#   'pages': 1,
#   'page': 1,
#   'responsetime': '5 ms'},
#  'records': [{'objectcount': 1,
#    'name': 'Natural History Specimens',
#    'id': 1133,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1133},
#   {'objectcount': 1,
#    'name': 'Paintings with Text',
#    'id': 197,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 197},
#   {'objectcount': 66,
#    'name': 'Performance Artifacts',
#    'id': 224,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 224},
#   {'objectcount': 1,
#    'name': 'Text',
#    'id': 204,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 204},
#   {'objectcount': 80,
#    'name': 'Tokens',
#    'id': 492,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 492},
#   {'objectcount': 62,
#    'name': 'Brick Stamps',
#    'id': 304,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 304},
#   {'objectcount': 46,
#    'name': 'Cameos',
#    'id': 1086,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1086},
#   {'objectcount': 1,
#    'name': 'Casts',
#    'id': 1139,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1139},
#   {'objectcount': 6,
#    'name': 'Containers',
#    'id': 1203,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1203},
#   {'objectcount': 11,
#    'name': 'Frames',
#    'id': 1188,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1188},
#   {'objectcount': 248,
#    'name': 'Gems',
#    'id': 1078,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1078},
#   {'objectcount': 16,
#    'name': 'Graphic Design',
#    'id': 171,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 171},
#   {'objectcount': 69,
#    'name': 'Inscriptions',
#    'id': 344,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 344},
#   {'objectcount': 344,
#    'name': 'Material Specimens',
#    'id': 1075,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1075},
#   {'objectcount': 470,
#    'name': 'Rubbings',
#    'id': 173,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 173},
#   {'objectcount': 351,
#    'name': '(not assigned)',
#    'id': 0,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 0},
#   {'objectcount': 2849,
#    'name': 'Accessories (non-art)',
#    'id': 2,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 2},
#   {'objectcount': 85763,
#    'name': 'Photographs',
#    'id': 17,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 17},
#   {'objectcount': 944,
#    'name': 'Jewelry',
#    'id': 19,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 19},
#   {'objectcount': 33727,
#    'name': 'Drawings',
#    'id': 21,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 21},
#   {'objectcount': 72270,
#    'name': 'Prints',
#    'id': 23,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 23},
#   {'objectcount': 7009,
#    'name': 'Paintings',
#    'id': 26,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 26},
#   {'objectcount': 6642,
#    'name': 'Sculpture',
#    'id': 30,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 30},
#   {'objectcount': 1416,
#    'name': 'Tools and Equipment',
#    'id': 32,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 32},
#   {'objectcount': 1287,
#    'name': 'Multiples',
#    'id': 43,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 43},
#   {'objectcount': 664,
#    'name': 'Lighting Devices',
#    'id': 45,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 45},
#   {'objectcount': 619,
#    'name': 'Books',
#    'id': 47,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 47},
#   {'objectcount': 20272,
#    'name': 'Coins',
#    'id': 50,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 50},
#   {'objectcount': 6229,
#    'name': 'Vessels',
#    'id': 57,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 57},
#   {'objectcount': 404,
#    'name': 'Plaques',
#    'id': 60,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 60},
#   {'objectcount': 3445,
#    'name': 'Textile Arts',
#    'id': 62,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 62},
#   {'objectcount': 15738,
#    'name': 'Archival Material',
#    'id': 64,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 64},
#   {'objectcount': 432,
#    'name': 'Audiovisual Works',
#    'id': 71,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 71},
#   {'objectcount': 613,
#    'name': 'Calligraphy',
#    'id': 75,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 75},
#   {'objectcount': 580,
#    'name': 'Furniture',
#    'id': 76,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 76},
#   {'objectcount': 157,
#    'name': 'Paintings with Calligraphy',
#    'id': 80,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 80},
#   {'objectcount': 88,
#    'name': 'Unidentified',
#    'id': 82,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 82},
#   {'objectcount': 335,
#    'name': 'Boxes',
#    'id': 85,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 85},
#   {'objectcount': 5212,
#    'name': 'Fragments',
#    'id': 94,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 94},
#   {'objectcount': 1536,
#    'name': "Artists' Tools",
#    'id': 97,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 97},
#   {'objectcount': 845,
#    'name': 'Medals and Medallions',
#    'id': 105,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 105},
#   {'objectcount': 57,
#    'name': 'Furnishings',
#    'id': 114,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 114},
#   {'objectcount': 1176,
#    'name': 'Architectural Elements',
#    'id': 133,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 133},
#   {'objectcount': 646,
#    'name': 'Timepieces',
#    'id': 139,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 139},
#   {'objectcount': 970,
#    'name': 'Ritual Implements',
#    'id': 146,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 146},
#   {'objectcount': 191,
#    'name': 'Mosaics',
#    'id': 149,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 149},
#   {'objectcount': 363,
#    'name': 'Weapons and Ammunition',
#    'id': 155,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 155},
#   {'objectcount': 46,
#    'name': 'Portfolios',
#    'id': 162,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 162},
#   {'objectcount': 134,
#    'name': 'Amulets',
#    'id': 180,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 180},
#   {'objectcount': 4921,
#    'name': 'Manuscripts',
#    'id': 185,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 185},
#   {'objectcount': 5899,
#    'name': 'Seals',
#    'id': 189,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 189},
#   {'objectcount': 63,
#    'name': 'Armor',
#    'id': 242,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 242},
#   {'objectcount': 181,
#    'name': 'Recreational Artifacts',
#    'id': 251,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 251},
#   {'objectcount': 171,
#    'name': 'Mirrors',
#    'id': 302,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 302},
#   {'objectcount': 70,
#    'name': 'Riding Equipment',
#    'id': 330,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 330},
#   {'objectcount': 32,
#    'name': 'Musical Instruments',
#    'id': 359,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 359},
#   {'objectcount': 77,
#    'name': 'Measuring Devices',
#    'id': 364,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 364},
#   {'objectcount': 49,
#    'name': 'Tablets',
#    'id': 381,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 381},
#   {'objectcount': 450,
#    'name': 'Albums',
#    'id': 384,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 384},
#   {'objectcount': 5127,
#    'name': 'Straus Materials',
#    'id': 959,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 959},
#   {'objectcount': 534,
#    'name': "Artists' Materials",
#    'id': 1012,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1012},
#   {'objectcount': 64,
#    'name': 'Stained Glass',
#    'id': 1088,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1088},
#   {'objectcount': 11,
#    'name': 'Models',
#    'id': 1137,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1137},
#   {'objectcount': 3,
#    'name': 'Documents',
#    'id': 1185,
#    'lastupdate': '2025-09-03T04:31:54-04:00',
#    'classificationid': 1185}]}

# %%
data.keys()
# Out:
# dict_keys(['info', 'records'])

# %%
data["info"]
# Out:
# {'totalrecordsperquery': 100,
#  'totalrecords': 64,
#  'pages': 1,
#  'page': 1,
#  'responsetime': '5 ms'}

# %%
data["records"]
# Out:
# [{'objectcount': 1,
#   'name': 'Natural History Specimens',
#   'id': 1133,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1133},
#  {'objectcount': 1,
#   'name': 'Paintings with Text',
#   'id': 197,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 197},
#  {'objectcount': 66,
#   'name': 'Performance Artifacts',
#   'id': 224,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 224},
#  {'objectcount': 1,
#   'name': 'Text',
#   'id': 204,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 204},
#  {'objectcount': 80,
#   'name': 'Tokens',
#   'id': 492,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 492},
#  {'objectcount': 62,
#   'name': 'Brick Stamps',
#   'id': 304,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 304},
#  {'objectcount': 46,
#   'name': 'Cameos',
#   'id': 1086,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1086},
#  {'objectcount': 1,
#   'name': 'Casts',
#   'id': 1139,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1139},
#  {'objectcount': 6,
#   'name': 'Containers',
#   'id': 1203,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1203},
#  {'objectcount': 11,
#   'name': 'Frames',
#   'id': 1188,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1188},
#  {'objectcount': 248,
#   'name': 'Gems',
#   'id': 1078,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1078},
#  {'objectcount': 16,
#   'name': 'Graphic Design',
#   'id': 171,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 171},
#  {'objectcount': 69,
#   'name': 'Inscriptions',
#   'id': 344,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 344},
#  {'objectcount': 344,
#   'name': 'Material Specimens',
#   'id': 1075,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1075},
#  {'objectcount': 470,
#   'name': 'Rubbings',
#   'id': 173,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 173},
#  {'objectcount': 351,
#   'name': '(not assigned)',
#   'id': 0,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 0},
#  {'objectcount': 2849,
#   'name': 'Accessories (non-art)',
#   'id': 2,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 2},
#  {'objectcount': 85763,
#   'name': 'Photographs',
#   'id': 17,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 17},
#  {'objectcount': 944,
#   'name': 'Jewelry',
#   'id': 19,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 19},
#  {'objectcount': 33727,
#   'name': 'Drawings',
#   'id': 21,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 21},
#  {'objectcount': 72270,
#   'name': 'Prints',
#   'id': 23,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 23},
#  {'objectcount': 7009,
#   'name': 'Paintings',
#   'id': 26,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 26},
#  {'objectcount': 6642,
#   'name': 'Sculpture',
#   'id': 30,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 30},
#  {'objectcount': 1416,
#   'name': 'Tools and Equipment',
#   'id': 32,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 32},
#  {'objectcount': 1287,
#   'name': 'Multiples',
#   'id': 43,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 43},
#  {'objectcount': 664,
#   'name': 'Lighting Devices',
#   'id': 45,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 45},
#  {'objectcount': 619,
#   'name': 'Books',
#   'id': 47,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 47},
#  {'objectcount': 20272,
#   'name': 'Coins',
#   'id': 50,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 50},
#  {'objectcount': 6229,
#   'name': 'Vessels',
#   'id': 57,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 57},
#  {'objectcount': 404,
#   'name': 'Plaques',
#   'id': 60,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 60},
#  {'objectcount': 3445,
#   'name': 'Textile Arts',
#   'id': 62,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 62},
#  {'objectcount': 15738,
#   'name': 'Archival Material',
#   'id': 64,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 64},
#  {'objectcount': 432,
#   'name': 'Audiovisual Works',
#   'id': 71,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 71},
#  {'objectcount': 613,
#   'name': 'Calligraphy',
#   'id': 75,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 75},
#  {'objectcount': 580,
#   'name': 'Furniture',
#   'id': 76,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 76},
#  {'objectcount': 157,
#   'name': 'Paintings with Calligraphy',
#   'id': 80,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 80},
#  {'objectcount': 88,
#   'name': 'Unidentified',
#   'id': 82,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 82},
#  {'objectcount': 335,
#   'name': 'Boxes',
#   'id': 85,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 85},
#  {'objectcount': 5212,
#   'name': 'Fragments',
#   'id': 94,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 94},
#  {'objectcount': 1536,
#   'name': "Artists' Tools",
#   'id': 97,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 97},
#  {'objectcount': 845,
#   'name': 'Medals and Medallions',
#   'id': 105,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 105},
#  {'objectcount': 57,
#   'name': 'Furnishings',
#   'id': 114,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 114},
#  {'objectcount': 1176,
#   'name': 'Architectural Elements',
#   'id': 133,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 133},
#  {'objectcount': 646,
#   'name': 'Timepieces',
#   'id': 139,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 139},
#  {'objectcount': 970,
#   'name': 'Ritual Implements',
#   'id': 146,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 146},
#  {'objectcount': 191,
#   'name': 'Mosaics',
#   'id': 149,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 149},
#  {'objectcount': 363,
#   'name': 'Weapons and Ammunition',
#   'id': 155,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 155},
#  {'objectcount': 46,
#   'name': 'Portfolios',
#   'id': 162,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 162},
#  {'objectcount': 134,
#   'name': 'Amulets',
#   'id': 180,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 180},
#  {'objectcount': 4921,
#   'name': 'Manuscripts',
#   'id': 185,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 185},
#  {'objectcount': 5899,
#   'name': 'Seals',
#   'id': 189,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 189},
#  {'objectcount': 63,
#   'name': 'Armor',
#   'id': 242,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 242},
#  {'objectcount': 181,
#   'name': 'Recreational Artifacts',
#   'id': 251,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 251},
#  {'objectcount': 171,
#   'name': 'Mirrors',
#   'id': 302,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 302},
#  {'objectcount': 70,
#   'name': 'Riding Equipment',
#   'id': 330,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 330},
#  {'objectcount': 32,
#   'name': 'Musical Instruments',
#   'id': 359,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 359},
#  {'objectcount': 77,
#   'name': 'Measuring Devices',
#   'id': 364,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 364},
#  {'objectcount': 49,
#   'name': 'Tablets',
#   'id': 381,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 381},
#  {'objectcount': 450,
#   'name': 'Albums',
#   'id': 384,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 384},
#  {'objectcount': 5127,
#   'name': 'Straus Materials',
#   'id': 959,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 959},
#  {'objectcount': 534,
#   'name': "Artists' Materials",
#   'id': 1012,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1012},
#  {'objectcount': 64,
#   'name': 'Stained Glass',
#   'id': 1088,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1088},
#  {'objectcount': 11,
#   'name': 'Models',
#   'id': 1137,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1137},
#  {'objectcount': 3,
#   'name': 'Documents',
#   'id': 1185,
#   'lastupdate': '2025-09-03T04:31:54-04:00',
#   'classificationid': 1185}]

# %%
len(data["records"])
# Out:
# 64

# %% [markdown]
# ## 2.Filtering Classifications which are >= 2500

# %%
classification_list=[]
for i in data["records"]:
    if i["objectcount"]>= 2500:
        classification_list.append (i["name"])
classification_list
# Out:
# ['Accessories (non-art)',
#  'Photographs',
#  'Drawings',
#  'Prints',
#  'Paintings',
#  'Sculpture',
#  'Coins',
#  'Vessels',
#  'Textile Arts',
#  'Archival Material',
#  'Fragments',
#  'Manuscripts',
#  'Seals',
#  'Straus Materials']

# %%
len(classification_list)
# Out:
# 14

# %% [markdown]
# ## 3.Writing a function to get 2500 objects from any one choosen classification

# %%
import requests
import pandas as pd
import random

api_key = "a50a2e2e-f9f5-4654-81c0-1a92d1ec9951"
url = "https://api.harvardartmuseums.org/object"  # Object URL

choosen_classification = random.choice(classification_list)
print(f"Your chosen classification is:{choosen_classification}")

def get_2500_objects(api_key,choosen_classification):
    object_list = []

    for i in range(1, 26):
        params = {
            "apikey": api_key,
            "size": 100,
            "page": i,
            "classification": choosen_classification
                }

        response = requests.get(url, params=params)

        data = response.json()
        records = data.get('records')
        object_list.extend(records) 
    print(f"Total objects collected :",len(object_list))
    return object_list
# Out:
# Your chosen classification is:Archival Material

# %%
# Calling the function
filtered_2500_objects = get_2500_objects(api_key,choosen_classification)
# Out:
# Total objects collected : 2500

# %%
filtered_2500_objects[0]
# Out:
# {'copyright': None,
#  'contextualtextcount': 0,
#  'creditline': 'Harvard Art Museums/Fogg Museum, Transfer from the Carpenter Center for the Visual Arts, Social Museum Collection',
#  'accesslevel': 1,
#  'createdate': '2006-03-20T00:00:00-05:00',
#  'dateoflastpageview': '2025-07-21',
#  'classificationid': 64,
#  'division': 'Modern and Contemporary Art',
#  'markscount': 0,
#  'publicationcount': 0,
#  'totaluniquepageviews': 40,
#  'contact': 'am_moderncontemporary@harvard.edu',
#  'colorcount': 8,
#  'rank': 8878,
#  'id': 4849,
#  'state': None,
#  'verificationleveldescription': 'Good. Object is well described and information is vetted',
#  'period': None,
#  'images': [{'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246584,
#    'idsid': 43316216,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21220',
#    'displayorder': 1,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21220_dynmc',
#    'alttext': None,
#    'width': 448,
#    'publiccaption': '2',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316216',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246585,
#    'idsid': 43316217,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21221',
#    'displayorder': 2,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21221_dynmc',
#    'alttext': None,
#    'width': 448,
#    'publiccaption': '3',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316217',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246586,
#    'idsid': 43316218,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21222',
#    'displayorder': 3,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21222_dynmc',
#    'alttext': None,
#    'width': 450,
#    'publiccaption': '4',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316218',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246587,
#    'idsid': 43316219,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21223',
#    'displayorder': 4,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21223_dynmc',
#    'alttext': None,
#    'width': 449,
#    'publiccaption': '5',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316219',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246588,
#    'idsid': 43316220,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21224',
#    'displayorder': 5,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21224_dynmc',
#    'alttext': None,
#    'width': 450,
#    'publiccaption': '6',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316220',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246589,
#    'idsid': 43316221,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21225',
#    'displayorder': 6,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21225_dynmc',
#    'alttext': None,
#    'width': 449,
#    'publiccaption': '7',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316221',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246590,
#    'idsid': 43316222,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21226',
#    'displayorder': 7,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21226_dynmc',
#    'alttext': None,
#    'width': 881,
#    'publiccaption': '8',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316222',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246591,
#    'idsid': 43316223,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21227',
#    'displayorder': 8,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21227_dynmc',
#    'alttext': None,
#    'width': 452,
#    'publiccaption': '9',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316223',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246592,
#    'idsid': 43316224,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21228',
#    'displayorder': 9,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21228_dynmc',
#    'alttext': None,
#    'width': 451,
#    'publiccaption': '10',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316224',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246593,
#    'idsid': 43316225,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21229',
#    'displayorder': 10,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21229_dynmc',
#    'alttext': None,
#    'width': 450,
#    'publiccaption': '11',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316225',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246594,
#    'idsid': 43316226,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21230',
#    'displayorder': 11,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21230_dynmc',
#    'alttext': None,
#    'width': 449,
#    'publiccaption': '12',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316226',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246595,
#    'idsid': 43316227,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21231',
#    'displayorder': 12,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21231_dynmc',
#    'alttext': None,
#    'width': 450,
#    'publiccaption': '13',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316227',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246596,
#    'idsid': 43316228,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21232',
#    'displayorder': 13,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21232_dynmc',
#    'alttext': None,
#    'width': 449,
#    'publiccaption': '14',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316228',
#    'height': 1024},
#   {'date': '2007-06-11',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 246597,
#    'idsid': 43316229,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'OCP21233',
#    'displayorder': 14,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21233_dynmc',
#    'alttext': None,
#    'width': 445,
#    'publiccaption': '15',
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43316229',
#    'height': 1024}],
#  'worktypes': [{'worktypeid': '255', 'worktype': 'pamphlet'}],
#  'imagecount': 14,
#  'totalpageviews': 68,
#  'accessionyear': 2011,
#  'standardreferencenumber': None,
#  'signed': None,
#  'classification': 'Archival Material',
#  'relatedcount': 1,
#  'verificationlevel': 3,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:OCP21220_dynmc',
#  'titlescount': 2,
#  'peoplecount': 1,
#  'style': None,
#  'lastupdate': '2025-09-03T04:57:36-04:00',
#  'commentary': None,
#  'periodid': None,
#  'technique': None,
#  'edition': None,
#  'description': None,
#  'medium': 'Printed pamphlet',
#  'lendingpermissionlevel': 0,
#  'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: How Thousands of Men Make Their Leisure Hours Count!: Some Opportunites Open to You at the Boston Young Men's Christian Association",
#  'accessionmethod': 'Transfer',
#  'colors': [{'color': '#fae1c8',
#    'spectrum': '#ed765a',
#    'hue': 'Yellow',
#    'percent': 0.901025641025641,
#    'css3': '#ffe4c4'},
#   {'color': '#c8c896',
#    'spectrum': '#a9cf38',
#    'hue': 'Green',
#    'percent': 0.07723076923076923,
#    'css3': '#d2b48c'},
#   {'color': '#afaf7d',
#    'spectrum': '#9ecb3b',
#    'hue': 'Green',
#    'percent': 0.020102564102564103,
#    'css3': '#bdb76b'},
#   {'color': '#7d7d64',
#    'spectrum': '#6cbd45',
#    'hue': 'Yellow',
#    'percent': 0.0009230769230769231,
#    'css3': '#808080'},
#   {'color': '#64644b',
#    'spectrum': '#59ba4a',
#    'hue': 'Green',
#    'percent': 0.00041025641025641023,
#    'css3': '#696969'},
#   {'color': '#323232',
#    'spectrum': '#2eb45d',
#    'hue': 'Grey',
#    'percent': 0.00010256410256410256,
#    'css3': '#2f4f4f'},
#   {'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.00010256410256410256,
#    'css3': '#dcdcdc'},
#   {'color': '#4b4b32',
#    'spectrum': '#4ab851',
#    'hue': 'Green',
#    'percent': 0.00010256410256410256,
#    'css3': '#556b2f'}],
#  'provenance': None,
#  'groupcount': 1,
#  'dated': '1920s',
#  'department': 'Department of Photographs',
#  'dateend': 1920,
#  'people': [{'role': 'Artist',
#    'birthplace': None,
#    'gender': 'unknown',
#    'displaydate': None,
#    'prefix': None,
#    'culture': None,
#    'displayname': 'Unidentified Artist',
#    'alphasort': 'Unidentified Artist',
#    'name': 'Unidentified Artist',
#    'personid': 34147,
#    'deathplace': None,
#    'displayorder': 1}],
#  'url': 'https://www.harvardartmuseums.org/collections/object/4849',
#  'dateoffirstpageview': '2009-09-22',
#  'century': '20th century',
#  'objectnumber': '3.2002.32.1',
#  'labeltext': None,
#  'datebegin': 1920,
#  'culture': 'American',
#  'exhibitioncount': 1,
#  'imagepermissionlevel': 0,
#  'mediacount': 0,
#  'objectid': 4849,
#  'techniqueid': None,
#  'dimensions': 'image: 23.5 x 10 cm (9 1/4 x 3 15/16 in.)',
#  'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/4849',
#    'type': 'IIIF Manifest',
#    'format': 'application/json',
#    'profile': 'http://iiif.io/api/presentation/2/context.json'}]}

# %%
filtered_2500_objects[0].keys()
# Out:
# dict_keys(['copyright', 'contextualtextcount', 'creditline', 'accesslevel', 'createdate', 'dateoflastpageview', 'classificationid', 'division', 'markscount', 'publicationcount', 'totaluniquepageviews', 'contact', 'colorcount', 'rank', 'id', 'state', 'verificationleveldescription', 'period', 'images', 'worktypes', 'imagecount', 'totalpageviews', 'accessionyear', 'standardreferencenumber', 'signed', 'classification', 'relatedcount', 'verificationlevel', 'primaryimageurl', 'titlescount', 'peoplecount', 'style', 'lastupdate', 'commentary', 'periodid', 'technique', 'edition', 'description', 'medium', 'lendingpermissionlevel', 'title', 'accessionmethod', 'colors', 'provenance', 'groupcount', 'dated', 'department', 'dateend', 'people', 'url', 'dateoffirstpageview', 'century', 'objectnumber', 'labeltext', 'datebegin', 'culture', 'exhibitioncount', 'imagepermissionlevel', 'mediacount', 'objectid', 'techniqueid', 'dimensions', 'seeAlso'])

# %%
for i in filtered_2500_objects[0].keys():
    print (i)
# Out:
# copyright
# contextualtextcount
# creditline
# accesslevel
# createdate
# dateoflastpageview
# classificationid
# division
# markscount
# publicationcount
# totaluniquepageviews
# contact
# colorcount
# rank
# id
# state
# verificationleveldescription
# period
# images
# worktypes
# imagecount
# totalpageviews
# accessionyear
# standardreferencenumber
# signed
# classification
# relatedcount
# verificationlevel
# primaryimageurl
# titlescount
# peoplecount
# style
# lastupdate
# commentary
# periodid
# technique
# edition
# description
# medium
# lendingpermissionlevel
# title
# accessionmethod
# colors
# provenance
# groupcount
# dated
# department
# dateend
# people
# url
# dateoffirstpageview
# century
# objectnumber
# labeltext
# datebegin
# culture
# exhibitioncount
# imagepermissionlevel
# mediacount
# objectid
# techniqueid
# dimensions
# seeAlso

# %% [markdown]
# ## 4.Filtering only essential fields

# %%
def filter_essential_fields(filtered_2500_objects):

      artifact_metadata = []
      artifact_media = []
      artifact_colors = []

      for i in filtered_2500_objects:
          artifact_metadata.append(dict(
              id = i['id'],
              title = i['title'],
              culture = i['culture'],
              period = i.get('period'),
              century = i['century'],
              medium = i.get('medium'),
              dimensions = i.get("dimensions"),
              description = i.get('description'),
              department = i["department"],
              classification = i['classification'],
              accessionyear = i['accessionyear'],
              accessionmethod = i['accessionmethod']))

          artifact_media.append(dict(
              objectid = i['objectid'],
              imagecount = i['imagecount'],
              mediacount = i['mediacount'],
              colorcount = i['colorcount'],
              rank = i['rank'],
              datebegin = i['datebegin'],
              dateend = i['dateend']))

          for j in i.get('colors', []):
              artifact_colors.append(dict(
                  objectid = i['objectid'],
                  color = j.get('color'),
                  spectrum= j.get('spectrum'),
                  hue = j['hue'],
                  percent = j['percent'],
                  css3 = j['css3']))

      return artifact_metadata,artifact_media,artifact_colors

# %%
# Calling the function
filter_essential_fields(filtered_2500_objects)
# Out:
# ([{'id': 4849,
#    'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: How Thousands of Men Make Their Leisure Hours Count!: Some Opportunites Open to You at the Boston Young Men's Christian Association",
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 23.5 x 10 cm (9 1/4 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4850,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Volunteer Varieties: Various Vocations for Volunteers in Social Work: The Volunteer Service Bureau: Auspices of the Boston Metropolitan Chapter American Red Cross.',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 17.4 x 9.5 cm (6 7/8 x 3 3/4 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4857,
#    'title': 'Art Theory Diagrams',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4879,
#    'title': 'Color Diagram for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '12.5 x 20 cm (4 15/16 x 7 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4880,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Bluc ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4881,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4882,
#    'title': 'Study for “Study for ‘Pochade’ #3”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red, and green ball-point ink on off-white wove paper',
#    'dimensions': '15.2 x 10.1 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4883,
#    'title': 'Study for “Study for ‘Pochade’ #2”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ink, black, red and blue crayon on off white wove paper',
#    'dimensions': '15.2 x 10 cm (6 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4884,
#    'title': 'Study for "Pochade"',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red, and green ball-point ink on off-white wove paper',
#    'dimensions': '20.2 x 12.5 cm (7 15/16 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4885,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4893,
#    'title': 'Study for ”Standard Still Life”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '10 x 15 cm (3 15/16 x 5 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4894,
#    'title': 'Study for “Study for ‘Pochade’ #2”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue, black, green and red ink on off white wove paper',
#    'dimensions': '15 x 10 cm (5 7/8 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4898,
#    'title': 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: James Loughlin. Jan. 21, 1904. Arithmetic.',
#    'culture': 'American',
#    'period': None,
#    'century': '19th-20th century',
#    'medium': 'Graphite on lined paper',
#    'dimensions': 'image: 26.6 x 20.3 cm (10 1/2 x 8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4902,
#    'title': 'Art Theory Text with Diagrams',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4903,
#    'title': 'Study for “’Art Digest’ Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4904,
#    'title': 'Art Theory Text with Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4912,
#    'title': 'Study for "Pochade"',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue, green, and red ball-point ink on off-white wove paper',
#    'dimensions': '20.1 x 12.5 cm (7 15/16 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4913,
#    'title': 'Art Theory Text with Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4914,
#    'title': 'Study for “Study for ‘Pochade’ #3”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '15 x 10 cm (5 7/8 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4915,
#    'title': 'Study for “Standard Still Life #2”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '10 x 15 cm (3 15/16 x 5 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4916,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4917,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4918,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4934,
#    'title': 'Study for “Something on the 8 Ball”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4935,
#    'title': 'Art Theory Text with Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4936,
#    'title': 'Color Diagram for “Tournos”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on off white wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4937,
#    'title': 'Study for “’Art Digest’ Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ink and graphpite on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4938,
#    'title': 'Study of “Columbia Records Album Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '21.6 x 27.9 cm (8 1/2 x 11 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4939,
#    'title': 'Study for “’Art Digest’ Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4944,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4945,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4949,
#    'title': 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: James Loughlin. Jan. 21, 1904. Arithmetic.',
#    'culture': 'American',
#    'period': None,
#    'century': '19th-20th century',
#    'medium': 'Graphite on lined paper',
#    'dimensions': 'image: 26.6 x 20.3 cm (10 1/2 x 8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4961,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Church Home Society for the Care of Children and Young People of the Protestant Episcopal Church',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 14.5 x 8.6 cm (5 11/16 x 3 3/8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4962,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Services July 1, 1927 - June 30, 1928: American Red Cross Boston Metropolitan Chapter',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 14.6 x 11.4 cm (5 3/4 x 4 1/2 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4966,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Co-operative Workrooms for Handicapped Women: A brief statement of the services rendered during the fiscal year October 1, 1927 to September 30, 1928',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.2 x 11 cm (6 x 4 5/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4967,
#    'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: A Two Week's Vacation at Boston Medical Mission: The Woman's Home Missionary Society. Methodist Episcopal Church",
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 19.5 x 10.3 cm (7 11/16 x 4 1/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4968,
#    'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Winter and Spring: General Education Department Young Women's Christian Association Boston, Massachusetts",
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.1 x 8.6 cm (5 15/16 x 3 3/8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 4983,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red, and green ball-point ink on off-white wove paper',
#    'dimensions': '20.2 x 12.5 cm (7 15/16 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4984,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4985,
#    'title': 'Study for “Pochade”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black, red and green ink on off white wove paper',
#    'dimensions': '12.5 x 20 cm (4 15/16 x 7 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 4999,
#    'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Health Education: Young Women's Christian Association",
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 14.9 x 8.5 cm (5 7/8 x 3 3/8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5000,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Boston Metropolitan Chapter American Red Cross: A Record of the Year 1926-1927',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.2 x 11.4 cm (6 x 4 1/2 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5001,
#    'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Where Friendless Girls are Welcome: Boston's Protective Agency: Welcome House --- Protective Committee of the Florence Crittenton League",
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.3 x 11 cm (6 x 4 5/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5002,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: A Few Words to Children about Some Other Children: Junior Division Massachusetts Society for the Prevention of Cruelty to Children',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 10.1 x 17.1 cm (4 x 6 3/4 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5003,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: South End House and its Neighborhood',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 19 x 10.8 cm (7 1/2 x 4 1/4 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5004,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Boston School of Occupational Therapy',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 13.3 x 10 cm (5 1/4 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5005,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: More Than One Way to Cook an Egg: The Food Clinic of The Boston Dispensary',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.9 x 9 cm (6 1/4 x 3 9/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5015,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Co-operative Workrooms for Handicapped Women: A brief statement of the services rendered during the fiscal year October 1, 1925 to September 30, 1926',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.2 x 10.9 cm (6 x 4 5/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5016,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: A Few Words to Children about Some Other Children: Junior Division Massachusetts Society for the Prevention of Cruelty to Children',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 10 x 17.1 cm (3 15/16 x 6 3/4 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5017,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Our Citizens: North Bennet Street Industrial School',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 16 x 15.6 cm (6 5/16 x 6 1/8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5018,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The New England Medical Center',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.2 x 9.6 cm (6 x 3 3/4 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5019,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: One Dozen Ways of Using One Glass of Skim Milk: The Food Clinic of The Boston Dispensary',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.9 x 8.9 cm (6 1/4 x 3 1/2 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5059,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Co-operative Workrooms for Handicapped Women',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 14.8 x 11.1 cm (5 13/16 x 4 3/8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5060,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Supposing No One Cared: Florence Crittenton League of Compassion, Inc.',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 12.2 x 17.6 cm (4 13/16 x 6 15/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5061,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: The Hospital Without Walls: Community Health Association',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 10.1 x 14 cm (4 x 5 1/2 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5119,
#    'title': 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Frank Blanchette. Jan. 28, 1904. Arithmetic.',
#    'culture': 'American',
#    'period': None,
#    'century': '19th-20th century',
#    'medium': 'Graphite on lined paper',
#    'dimensions': 'image: 26.6 x 20.3 cm (10 1/2 x 8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5120,
#    'title': 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Frank Blanchette. Jan. 28, 1904. Arithmetic.',
#    'culture': 'American',
#    'period': None,
#    'century': '19th-20th century',
#    'medium': 'Graphite on lined paper',
#    'dimensions': 'image: 26.6 x 20.3 cm (10 1/2 x 8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5122,
#    'title': 'Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5123,
#    'title': 'Art Theory Text with Horses and Riders',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on tan wove paper',
#    'dimensions': '27.94 x 21.59 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5124,
#    'title': 'Study for "Ursine Park"',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink and graphite on tan wove paper',
#    'dimensions': '27.7 x 21.6 cm (10 7/8 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5125,
#    'title': 'Study for “Ursine Park”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink and graphite on tan wove paper',
#    'dimensions': '27.94 x 21.59 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5126,
#    'title': 'Study for “Ursine Park”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink and graphite on tan wove paper',
#    'dimensions': '27.94 x 21.59 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5127,
#    'title': 'Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '27 x 20.6 cm (10 5/8 x 8 1/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5128,
#    'title': 'Art Theory Text with Diagram',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '27 x 20.6 cm (10 5/8 x 8 1/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5129,
#    'title': 'Art Theory Text with Gesture Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5130,
#    'title': 'Art Theory Text with Gesture Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5131,
#    'title': 'Study for “Cliché” and “Ready-to-Wear”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5132,
#    'title': 'Study for “Cliché” and “Ready-to-Wear”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5133,
#    'title': 'Study for “Cliché” and “Ready-to-Wear”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5134,
#    'title': 'Study for “Cliché” and “Ready-to-Wear”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5135,
#    'title': 'Study for “Ready-to-Wear”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5147,
#    'title': 'Study for “Cliché”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off-white wove paper',
#    'dimensions': '15.24 x 10.16 cm (6 x 4 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5148,
#    'title': 'Art Theory Text with Sketches',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '15 x 10 cm (5 7/8 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5149,
#    'title': 'Calligraphic Tone Diagram',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '15 x 10 cm (5 7/8 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5150,
#    'title': 'Art Theory Text with Minimum and Maximum Ratio Differential Diagrams',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '10 x 15 cm (3 15/16 x 5 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5151,
#    'title': 'Art Theory Text with Minimum and Maximum Ratio Differential Diagram',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '10 x 15 cm (3 15/16 x 5 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5152,
#    'title': 'Crime, Children, Truant Schools: United States. Massachusetts. Oakdale. Worcester County Truant School: Worcester County Truant School, Oakdale.: Frank McDonald. Jan. 22, 1904. Arithmetic.',
#    'culture': 'American',
#    'period': None,
#    'century': '19th-20th century',
#    'medium': 'Graphite on lined paper',
#    'dimensions': 'image: 26.6 x 20.3 cm (10 1/2 x 8 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5157,
#    'title': 'Art Theory Text with Maximum Ratio Differential Diagram',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '10 x 15 cm (3 15/16 x 5 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5158,
#    'title': 'Art Theory Text with Star and Diagram',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '15 x 10 cm (5 7/8 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5159,
#    'title': 'Art Theory Text with Sketches',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '15 x 10 cm (5 7/8 x 3 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5160,
#    'title': 'A and B Figure Fields',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.7 cm (7 7/8 x 5 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5161,
#    'title': 'Study for “UFO”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ink on cream wove paper',
#    'dimensions': '20.3 x 12.7 cm (8 x 5 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5162,
#    'title': 'Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ink on cream wove paper',
#    'dimensions': '20.3 x 12.7 cm (8 x 5 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5163,
#    'title': 'Art Theory Text with Context Figure Diagrams',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Blue ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5164,
#    'title': 'Art Theory Text with Diagram',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5165,
#    'title': 'Study for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5166,
#    'title': 'Color Diagram for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point  pen and crayon on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5167,
#    'title': 'Study for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5168,
#    'title': 'Study for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '20 x 12.5 cm (7 7/8 x 4 15/16 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5169,
#    'title': 'Study for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '12.5 x 20 cm (4 15/16 x 7 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5170,
#    'title': 'Study for “Composition Concrete”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ball-point ink on off white wove paper',
#    'dimensions': '12.5 x 20 cm (4 15/16 x 7 7/8 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5171,
#    'title': 'Preliminary Study for “Columbia Records Album Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '28.2 x 21.6 cm (11 1/8 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5172,
#    'title': 'Preliminary Study for “Columbia Records Album Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '28.2 x 21.6 cm (11 1/8 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5237,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Service Continuation Fund: Boston Y.W.C.A.',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 21.6 x 10.1 cm (8 1/2 x 4 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5238,
#    'title': 'Art Theory Text with Study for “Something on the 8 Ball”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5239,
#    'title': 'Study for “Something on the 8 Ball”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5266,
#    'title': 'Method as Meaning',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5267,
#    'title': 'Study for “Natural Scene”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5268,
#    'title': 'Study for “Tournos”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on off white wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5273,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Adopting a Child: Blessing or Tragedy?: Massachusetts Civic League, Inc.',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 15.5 x 9 cm (6 1/8 x 3 9/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5274,
#    'title': 'Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: Boston Metropolitan Chapter American Red Cross: A Record of the Tenth Year',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 18.3 x 9.4 cm (7 3/16 x 3 11/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5280,
#    'title': 'Preliminary Study for “’Art Digest’ Cover”',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5281,
#    'title': 'Sketch',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5282,
#    'title': 'Sequence-Object Diagrams',
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Black ink on tan wove paper',
#    'dimensions': '27.9 x 21.6 cm (11 x 8 1/2 in.)',
#    'description': None,
#    'department': 'Department of Drawings',
#    'classification': 'Archival Material',
#    'accessionyear': 1967,
#    'accessionmethod': 'Gift'},
#   {'id': 5284,
#    'title': "Charity, Organizations: United States. Massachusetts. Boston. Publicity for Social Work: Booklets: That Meddlin' Society: The Society for the Prevention of Cruelty to Children",
#    'culture': 'American',
#    'period': None,
#    'century': '20th century',
#    'medium': 'Printed pamphlet',
#    'dimensions': 'image: 18.5 x 9 cm (7 5/16 x 3 9/16 in.)',
#    'description': None,
#    'department': 'Department of Photographs',
#    'classification': 'Archival Material',
#    'accessionyear': 2011,
#    'accessionmethod': 'Transfer'},
#   {'id': 5285,
# ...
#    'color': '#323219',
#    'spectrum': '#3db657',
#    'hue': 'Brown',
#    'percent': 0.00463768115942029,
#    'css3': '#2f4f4f'},
#   {'objectid': 5387,
#    'color': '#af7d4b',
#    'spectrum': '#e9715f',
#    'hue': 'Yellow',
#    'percent': 0.7394827586206897,
#    'css3': '#cd853f'},
#   {'objectid': 5387,
#    'color': '#c89664',
#    'spectrum': '#ed7758',
#    'hue': 'Brown',
#    'percent': 0.2071264367816092,
#    'css3': '#bdb76b'},
#   {'objectid': 5387,
#    'color': '#c8afaf',
#    'spectrum': '#b55592',
#    'hue': 'Red',
#    'percent': 0.02281609195402299,
#    'css3': '#c0c0c0'},
#   {'objectid': 5387,
#    'color': '#644b32',
#    'spectrum': '#59ba4a',
#    'hue': 'Brown',
#    'percent': 0.015747126436781608,
#    'css3': '#556b2f'},
#   {'objectid': 5387,
#    'color': '#4b3232',
#    'spectrum': '#4ab851',
#    'hue': 'Red',
#    'percent': 0.010344827586206896,
#    'css3': '#2f4f4f'},
#   {'objectid': 5387,
#    'color': '#c8c8c8',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.004482758620689655,
#    'css3': '#c0c0c0'},
#   {'objectid': 5388,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.9040579710144927,
#    'css3': '#deb887'},
#   {'objectid': 5388,
#    'color': '#e19664',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.03756521739130435,
#    'css3': '#e9967a'},
#   {'objectid': 5388,
#    'color': '#af9664',
#    'spectrum': '#e9715f',
#    'hue': 'Yellow',
#    'percent': 0.03455072463768116,
#    'css3': '#bdb76b'},
#   {'objectid': 5388,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.019304347826086955,
#    'css3': '#dcdcdc'},
#   {'objectid': 5388,
#    'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.004057971014492754,
#    'css3': '#808080'},
#   {'objectid': 5388,
#    'color': '#646464',
#    'spectrum': '#7866ad',
#    'hue': 'Grey',
#    'percent': 0.00046376811594202896,
#    'css3': '#696969'},
#   {'objectid': 5389,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.7959770114942529,
#    'css3': '#deb887'},
#   {'objectid': 5389,
#    'color': '#c89664',
#    'spectrum': '#ed7758',
#    'hue': 'Brown',
#    'percent': 0.17660919540229886,
#    'css3': '#bdb76b'},
#   {'objectid': 5389,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.024022988505747127,
#    'css3': '#dcdcdc'},
#   {'objectid': 5389,
#    'color': '#e1c8c8',
#    'spectrum': '#c15689',
#    'hue': 'Orange',
#    'percent': 0.0033908045977011493,
#    'css3': '#d8bfd8'},
#   {'objectid': 5390,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.8097126436781609,
#    'css3': '#deb887'},
#   {'objectid': 5390,
#    'color': '#c89664',
#    'spectrum': '#ed7758',
#    'hue': 'Brown',
#    'percent': 0.1635632183908046,
#    'css3': '#bdb76b'},
#   {'objectid': 5390,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.013160919540229885,
#    'css3': '#dcdcdc'},
#   {'objectid': 5390,
#    'color': '#e1c8c8',
#    'spectrum': '#c15689',
#    'hue': 'Orange',
#    'percent': 0.012988505747126436,
#    'css3': '#d8bfd8'},
#   {'objectid': 5390,
#    'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.0005747126436781609,
#    'css3': '#696969'},
#   {'objectid': 5391,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.9739655172413794,
#    'css3': '#deb887'},
#   {'objectid': 5391,
#    'color': '#e1c8c8',
#    'spectrum': '#c15689',
#    'hue': 'Orange',
#    'percent': 0.01747126436781609,
#    'css3': '#d8bfd8'},
#   {'objectid': 5391,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.008563218390804598,
#    'css3': '#dcdcdc'},
#   {'objectid': 5392,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.9382183908045977,
#    'css3': '#deb887'},
#   {'objectid': 5392,
#    'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.02,
#    'css3': '#808080'},
#   {'objectid': 5392,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.017586206896551725,
#    'css3': '#dcdcdc'},
#   {'objectid': 5392,
#    'color': '#e1c8c8',
#    'spectrum': '#c15689',
#    'hue': 'Orange',
#    'percent': 0.01689655172413793,
#    'css3': '#d8bfd8'},
#   {'objectid': 5392,
#    'color': '#7d6464',
#    'spectrum': '#8e5ea7',
#    'hue': 'Brown',
#    'percent': 0.005229885057471264,
#    'css3': '#696969'},
#   {'objectid': 5392,
#    'color': '#644b4b',
#    'spectrum': '#8362aa',
#    'hue': 'Brown',
#    'percent': 0.0020689655172413794,
#    'css3': '#696969'},
#   {'objectid': 5393,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.9656811594202899,
#    'css3': '#deb887'},
#   {'objectid': 5393,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.01808695652173913,
#    'css3': '#dcdcdc'},
#   {'objectid': 5393,
#    'color': '#c8c8c8',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.012521739130434783,
#    'css3': '#c0c0c0'},
#   {'objectid': 5393,
#    'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.0033043478260869567,
#    'css3': '#808080'},
#   {'objectid': 5393,
#    'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.00040579710144927536,
#    'css3': '#696969'},
#   {'objectid': 5394,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.9854654654654654,
#    'css3': '#dcdcdc'},
#   {'objectid': 5394,
#    'color': '#c8c8c8',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.014474474474474475,
#    'css3': '#c0c0c0'},
#   {'objectid': 5394,
#    'color': '#9696af',
#    'spectrum': '#8163ab',
#    'hue': 'Blue',
#    'percent': 6.006006006006006e-05,
#    'css3': '#a9a9a9'},
#   {'objectid': 5395,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.940060606060606,
#    'css3': '#dcdcdc'},
#   {'objectid': 5395,
#    'color': '#c8c8c8',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.059393939393939395,
#    'css3': '#c0c0c0'},
#   {'objectid': 5395,
#    'color': '#9696af',
#    'spectrum': '#8163ab',
#    'hue': 'Blue',
#    'percent': 0.0005454545454545455,
#    'css3': '#a9a9a9'},
#   {'objectid': 5396,
#    'color': '#c8c8af',
#    'spectrum': '#b55592',
#    'hue': 'Green',
#    'percent': 0.7808666666666667,
#    'css3': '#c0c0c0'},
#   {'objectid': 5396,
#    'color': '#afafaf',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.0932,
#    'css3': '#a9a9a9'},
#   {'objectid': 5396,
#    'color': '#9696af',
#    'spectrum': '#8163ab',
#    'hue': 'Blue',
#    'percent': 0.0638,
#    'css3': '#a9a9a9'},
#   {'objectid': 5396,
#    'color': '#647daf',
#    'spectrum': '#656cb2',
#    'hue': 'Blue',
#    'percent': 0.020133333333333333,
#    'css3': '#4682b4'},
#   {'objectid': 5396,
#    'color': '#324b96',
#    'spectrum': '#4072b8',
#    'hue': 'Blue',
#    'percent': 0.016266666666666665,
#    'css3': '#483d8b'},
#   {'objectid': 5396,
#    'color': '#4b6496',
#    'spectrum': '#536fb5',
#    'hue': 'Blue',
#    'percent': 0.016066666666666667,
#    'css3': '#483d8b'},
#   {'objectid': 5396,
#    'color': '#19327d',
#    'spectrum': '#2474ba',
#    'hue': 'Blue',
#    'percent': 0.009333333333333334,
#    'css3': '#191970'},
#   {'objectid': 5396,
#    'color': '#7d647d',
#    'spectrum': '#8362aa',
#    'hue': 'Violet',
#    'percent': 0.0002666666666666667,
#    'css3': '#808080'},
#   {'objectid': 5396,
#    'color': '#321964',
#    'spectrum': '#4f6fb6',
#    'hue': 'Violet',
#    'percent': 6.666666666666667e-05,
#    'css3': '#191970'},
#   {'objectid': 5397,
#    'color': '#c8c8af',
#    'spectrum': '#b55592',
#    'hue': 'Green',
#    'percent': 0.8574149659863946,
#    'css3': '#c0c0c0'},
#   {'objectid': 5397,
#    'color': '#afafaf',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.09387755102040816,
#    'css3': '#a9a9a9'},
#   {'objectid': 5397,
#    'color': '#9696af',
#    'spectrum': '#8163ab',
#    'hue': 'Blue',
#    'percent': 0.04870748299319728,
#    'css3': '#a9a9a9'},
#   {'objectid': 5398,
#    'color': '#c8c8af',
#    'spectrum': '#b55592',
#    'hue': 'Green',
#    'percent': 0.8688215488215488,
#    'css3': '#c0c0c0'},
#   {'objectid': 5398,
#    'color': '#afafaf',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.07198653198653199,
#    'css3': '#a9a9a9'},
#   {'objectid': 5398,
#    'color': '#969696',
#    'spectrum': '#8761aa',
#    'hue': 'Grey',
#    'percent': 0.056228956228956226,
#    'css3': '#a9a9a9'},
#   {'objectid': 5398,
#    'color': '#4b6496',
#    'spectrum': '#536fb5',
#    'hue': 'Blue',
#    'percent': 0.0026936026936026937,
#    'css3': '#483d8b'},
#   {'objectid': 5398,
#    'color': '#19327d',
#    'spectrum': '#2474ba',
#    'hue': 'Blue',
#    'percent': 0.00020202020202020202,
#    'css3': '#191970'},
#   {'objectid': 5398,
#    'color': '#324b7d',
#    'spectrum': '#4072b8',
#    'hue': 'Blue',
#    'percent': 6.734006734006734e-05,
#    'css3': '#483d8b'},
#   {'objectid': 5399,
#    'color': '#c8c8af',
#    'spectrum': '#b55592',
#    'hue': 'Green',
#    'percent': 0.663,
#    'css3': '#c0c0c0'},
#   {'objectid': 5399,
#    'color': '#969696',
#    'spectrum': '#8761aa',
#    'hue': 'Grey',
#    'percent': 0.11853333333333334,
#    'css3': '#a9a9a9'},
#   {'objectid': 5399,
#    'color': '#c8af96',
#    'spectrum': '#e66c64',
#    'hue': 'Brown',
#    'percent': 0.11786666666666666,
#    'css3': '#d2b48c'},
#   {'objectid': 5399,
#    'color': '#afafaf',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.0942,
#    'css3': '#a9a9a9'},
#   {'objectid': 5399,
#    'color': '#4b6496',
#    'spectrum': '#536fb5',
#    'hue': 'Blue',
#    'percent': 0.005333333333333333,
#    'css3': '#483d8b'},
#   {'objectid': 5399,
#    'color': '#324b96',
#    'spectrum': '#4072b8',
#    'hue': 'Blue',
#    'percent': 0.0010666666666666667,
#    'css3': '#483d8b'},
#   {'objectid': 5401,
#    'color': '#e1c896',
#    'spectrum': '#ed765a',
#    'hue': 'Yellow',
#    'percent': 0.6327586206896552,
#    'css3': '#deb887'},
#   {'objectid': 5401,
#    'color': '#c8af96',
#    'spectrum': '#e66c64',
#    'hue': 'Brown',
#    'percent': 0.20344827586206896,
#    'css3': '#d2b48c'},
#   {'objectid': 5401,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.1214367816091954,
#    'css3': '#deb887'},
#   {'objectid': 5401,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.0267816091954023,
#    'css3': '#dcdcdc'},
#   {'objectid': 5401,
#    'color': '#af967d',
#    'spectrum': '#c25687',
#    'hue': 'Brown',
#    'percent': 0.013793103448275862,
#    'css3': '#bc8f8f'},
#   {'objectid': 5401,
#    'color': '#c89664',
#    'spectrum': '#ed7758',
#    'hue': 'Brown',
#    'percent': 0.001781609195402299,
#    'css3': '#bdb76b'},
#   {'objectid': 5402,
#    'color': '#e1c896',
#    'spectrum': '#ed765a',
#    'hue': 'Yellow',
#    'percent': 0.6687356321839081,
#    'css3': '#deb887'},
#   {'objectid': 5402,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.30258620689655175,
#    'css3': '#deb887'},
#   {'objectid': 5402,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.019597701149425287,
#    'css3': '#dcdcdc'},
#   {'objectid': 5402,
#    'color': '#afafaf',
#    'spectrum': '#8c5fa8',
#    'hue': 'Grey',
#    'percent': 0.006666666666666667,
#    'css3': '#a9a9a9'},
#   {'objectid': 5402,
#    'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.0018390804597701149,
#    'css3': '#808080'},
#   {'objectid': 5402,
#    'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.00028735632183908046,
#    'css3': '#696969'},
#   {'objectid': 5402,
#    'color': '#644b4b',
#    'spectrum': '#8362aa',
#    'hue': 'Brown',
#    'percent': 0.00022988505747126436,
#    'css3': '#696969'},
#   {'objectid': 5402,
#    'color': '#4b3232',
#    'spectrum': '#4ab851',
#    'hue': 'Red',
#    'percent': 5.747126436781609e-05,
#    'css3': '#2f4f4f'},
#   {'objectid': 5403,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.9006376811594203,
#    'css3': '#deb887'},
#   {'objectid': 5403,
#    'color': '#c8967d',
#    'spectrum': '#e66c64',
#    'hue': 'Grey',
#    'percent': 0.07420289855072464,
#    'css3': '#bc8f8f'},
#   {'objectid': 5403,
#    'color': '#e1c8af',
#    'spectrum': '#e9715f',
#    'hue': 'Orange',
#    'percent': 0.012463768115942029,
#    'css3': '#f5deb3'},
#   {'objectid': 5403,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.01182608695652174,
#    'css3': '#dcdcdc'},
#   {'objectid': 5403,
#    'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.0008695652173913044,
#    'css3': '#696969'},
#   {'objectid': 5404,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.6982028985507246,
#    'css3': '#deb887'},
#   {'objectid': 5404,
#    'color': '#e1c896',
#    'spectrum': '#ed765a',
#    'hue': 'Yellow',
#    'percent': 0.14655072463768115,
#    'css3': '#deb887'},
#   {'objectid': 5404,
#    'color': '#e19664',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.12805797101449276,
#    'css3': '#e9967a'},
#   {'objectid': 5404,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.01617391304347826,
#    'css3': '#dcdcdc'},
#   {'objectid': 5404,
#    'color': '#e1c8c8',
#    'spectrum': '#c15689',
#    'hue': 'Orange',
#    'percent': 0.009739130434782608,
#    'css3': '#d8bfd8'},
#   {'objectid': 5404,
#    'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.0012753623188405797,
#    'css3': '#808080'},
#   {'objectid': 5405,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.5726376811594203,
#    'css3': '#deb887'},
#   {'objectid': 5405,
#    'color': '#c8964b',
#    'spectrum': '#f58843',
#    'hue': 'Yellow',
#    'percent': 0.3396521739130435,
#    'css3': '#cd853f'},
#   {'objectid': 5405,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.049217391304347824,
#    'css3': '#dcdcdc'},
#   {'objectid': 5405,
#    'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.016289855072463767,
#    'css3': '#696969'},
#   {'objectid': 5405,
#    'color': '#e1c8c8',
#    'spectrum': '#c15689',
#    'hue': 'Orange',
#    'percent': 0.01327536231884058,
#    'css3': '#d8bfd8'},
#   {'objectid': 5405,
#    'color': '#644b32',
#    'spectrum': '#59ba4a',
#    'hue': 'Brown',
#    'percent': 0.007594202898550725,
#    'css3': '#556b2f'},
#   {'objectid': 5405,
#    'color': '#323219',
#    'spectrum': '#3db657',
#    'hue': 'Brown',
#    'percent': 0.0009275362318840579,
#    'css3': '#2f4f4f'},
#   {'objectid': 5405,
#    'color': '#191919',
#    'spectrum': '#1eb264',
#    'hue': 'Grey',
#    'percent': 0.00040579710144927536,
#    'css3': '#000000'},
#   {'objectid': 5406,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.5803478260869566,
#    'css3': '#deb887'},
#   {'objectid': 5406,
#    'color': '#e1c896',
#    'spectrum': '#ed765a',
#    'hue': 'Yellow',
#    'percent': 0.22028985507246376,
#    'css3': '#deb887'},
#   {'objectid': 5406,
#    'color': '#c89664',
#    'spectrum': '#ed7758',
#    'hue': 'Brown',
#    'percent': 0.1303768115942029,
#    'css3': '#bdb76b'},
#   {'objectid': 5406,
#    'color': '#e1e1e1',
#    'spectrum': '#955ba5',
#    'hue': 'Grey',
#    'percent': 0.0416231884057971,
#    'css3': '#dcdcdc'},
#   {'objectid': 5406,
#    'color': '#967d4b',
#    'spectrum': '#7fc241',
#    'hue': 'Brown',
#    'percent': 0.01571014492753623,
#    'css3': '#a0522d'},
#   {'objectid': 5406,
#    'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.007478260869565217,
#    'css3': '#696969'},
#   {'objectid': 5406,
#    'color': '#644b32',
#    'spectrum': '#59ba4a',
#    'hue': 'Brown',
#    'percent': 0.0037681159420289855,
#    'css3': '#556b2f'},
#   {'objectid': 5406,
#    'color': '#323219',
#    'spectrum': '#3db657',
#    'hue': 'Brown',
#    'percent': 0.00034782608695652176,
#    'css3': '#2f4f4f'},
#   {'objectid': 5406,
#    'color': '#c87d32',
#    'spectrum': '#f58444',
#    'hue': 'Brown',
#    'percent': 5.797101449275362e-05,
#    'css3': '#cd853f'},
#   {'objectid': 5407,
#    'color': '#e1af7d',
#    'spectrum': '#ef7a55',
#    'hue': 'Orange',
#    'percent': 0.5637606837606838,
#    'css3': '#deb887'},
#   ...])

# %%
len(filter_essential_fields(filtered_2500_objects))
# Out:
# 3

# %%
artifact_metadata,artifact_media,artifact_colors = filter_essential_fields(filtered_2500_objects)

# %%
len(artifact_metadata)
# Out:
# 2500

# %%
len(artifact_media)
# Out:
# 2500

# %%
len(artifact_colors)
# Out:
# 16320

# %% [markdown]
# ## 5.SQL

# %% [markdown]
# ### 1.Giving Connection

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-pythonNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading mysql_connector_python-9.4.0-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Downloading mysql_connector_python-9.4.0-cp313-cp313-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.4 MB 3.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.6/16.4 MB 3.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.4/16.4 MB 3.6 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/16.4 MB 3.7 MB/s eta 0:00:04
#    -------- ------------------------------- 3.7/16.4 MB 3.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.5/16.4 MB 3.7 MB/s eta 0:00:04
#    ------------ --------------------------- 5.2/16.4 MB 3.7 MB/s eta 0:00:04
#    -------------- ------------------------- 6.0/16.4 MB 3.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.8/16.4 MB 3.7 MB/s eta 0:00:03
#    ------------------ --------------------- 7.6/16.4 MB 3.7 MB/s eta 0:00:03
#    ------------------- -------------------- 8.1/16.4 MB 3.7 MB/s eta 0:00:03
#    --------------------- ------------------ 8.9/16.4 MB 3.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.7/16.4 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.4 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 11.3/16.4 MB 3.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.1/16.4 MB 3.7 MB/s eta 0:00:02
#    ------------------------------- -------- 12.8/16.4 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 13.4/16.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.2/16.4 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 15.5/16.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 3.6 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.4.0

# %%
import mysql.connector
conn = mysql.connector.connect(
    host="localhost",
    user="root",        # change if different
    password="root"  # replace with your MySQL password
)
cursor = conn.cursor()

# %% [markdown]
# ### 2.Create Database

# %%
cursor.execute("CREATE DATABASE IF NOT EXISTS harvard")
cursor.execute("USE harvard")   # switch to it

# %% [markdown]
# ### 3.Create Tables

# %%
def create_tables():
    #1
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS artifact_metadata (
            id INT PRIMARY KEY,
            title TEXT,
            culture TEXT,
            `period` TEXT,
            century TEXT,
            medium TEXT,
            dimensions TEXT,
            description TEXT,
            department TEXT,
            classification TEXT,
            accessionyear INT,
            accessionmethod TEXT
        )
    """)
    #2
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS artifact_media (
            objectid INT PRIMARY KEY,
            imagecount INT,
            mediacount INT,
            colorcount INT,
            rankk INT,
            datebegin INT,
            dateend INT,
            FOREIGN KEY (objectid) REFERENCES artifact_metadata(id)
        )
    """)
    #3
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS artifact_colors (
            id INT AUTO_INCREMENT PRIMARY KEY,
            objectid INT,
            color VARCHAR(10),
            spectrum VARCHAR(10),
            hue VARCHAR(50),
            percent DECIMAL(12,10),
            css3 VARCHAR(10),
            FOREIGN KEY (objectid) REFERENCES artifact_media(objectid)
        )
    """)

# Calling the function
create_tables()

# %% [markdown]
# ### 4.Insert Data

# %%
def insert_values(artifact_metadata,artifact_media,artifact_colors):
    # Insert query 
    #1
    insert_artifact_metadata = """
        INSERT INTO artifact_metadata 
        (id, title, culture, `period`, century, medium, dimensions, description, department, classification, accessionyear, accessionmethod) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    #2
    insert_artifact_media  = """
        INSERT INTO artifact_media 
        (objectid, imagecount, mediacount, colorcount, rankk, datebegin, dateend)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
    """
    #3
    insert_artifact_colors = """
        INSERT INTO artifact_colors
        (objectid, color, spectrum, hue, percent, css3)
        VALUES (%s, %s, %s, %s, %s, %s)
    """
    # Insert loop
    #1
    for row in artifact_metadata:
        values1 = (
            row.get('id'),
            row.get('title', ''),
            row.get('culture', ''),
            row.get('period', ''),
            row.get('century', ''),
            row.get('medium', ''),
            row.get('dimensions', ''),
            row.get('description', ''),
            row.get('department', ''),
            row.get('classification', ''),
            row.get('accessionyear'),
            row.get('accessionmethod', '')
        )
        cursor.execute(insert_artifact_metadata, values1)
        
    #2
    for i in artifact_media: 
        values2 = (
            i.get('objectid'),
            i.get('imagecount', 0),
            i.get('mediacount', 0),
            i.get('colorcount', 0),
            i.get('rankk', 0),
            i.get('datebegin'),
            i.get('dateend')
        )
        cursor.execute(insert_artifact_media, values2)
    #3
    for row in artifact_colors:
        values3 = (
            row.get('objectid'),
            row.get('color'),
            row.get('spectrum'),
            row.get('hue'),
            row.get('percent'),
            row.get('css3')
        )
        cursor.execute(insert_artifact_colors,values3)
    
    # Commit after loop
    conn.commit()

# Calling the function
insert_values(artifact_metadata,artifact_media,artifact_colors)

# %% [markdown]
# ## 6.Streamlit

# %%
# Refer VS Code(harvard.py)
